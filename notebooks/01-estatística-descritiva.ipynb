# %%
import pandas as pd
import seaborn as sns

# %%
df = sns.load_dataset('tips')

# %%
ds = sns.load_dataset('titanic')

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df_dict = pd.DataFrame([
    {
        "variavel":"total_bill",
        "descricao":"conta total",
        "tipo": "quantitativa",
        "subtipo": "contínuas"
    },{
        "variavel": "tip",
        "descricao": "gorjeta",
        "tipo": "quantitativa",
        "subtipo": "contínua",
    },{
        "variavel":"sex",
        "descricao": "refere-se ao sexo da pessoa",
        "tipo":"qualitativa",
        "subtipo":"nominal",
    },{
        "variavel":"smoker",
        "descricao": "condição se a pessoa é fumante ou não",
        "tipo":"qualitativa",
        "subtipo":"nominal",
    },{
        "variavel":"day",
        "descricao":"dia da semana",
        "tipo":"qualitativa",
        "subtipo":"ordinal",
    },{
        "variavel":"time",
        "descricao":"tempo",
        "tipo":"qualitativa",
        "subtipo":"ordinal",
    },{
        "variavel":"size",
        "descricao":"tamanho",
        "tipo":"quantitativa",
        "subtipo":"contínua",
    }
    
])

df_dict
# Out:
#      variavel                              descricao          tipo    subtipo
# 0  total_bill                            conta total  quantitativa  contínuas
# 1         tip                                gorjeta  quantitativa   contínua
# 2         sex            refere-se ao sexo da pessoa   qualitativa    nominal
# 3      smoker  condição se a pessoa é fumante ou não   qualitativa    nominal
# 4         day                          dia da semana   qualitativa    ordinal
# 5        time                                  tempo   qualitativa    ordinal
# 6        size                                tamanho  quantitativa   contínua

# %%
qualitativos=df[['sex', 'smoker', 'day', 'time']].mode()

for variavel in qualitativos:
    valores_unicos = df[variavel].unique()
    for valor in valores_unicos:
        print(f"{variavel} - {valor}")
        subamostras = df[df[variavel] == valor]
        print(subamostras.describe())
# Out:
# sex - Female
#        total_bill        tip       size
# count   87.000000  87.000000  87.000000
# mean    18.056897   2.833448   2.459770
# std      8.009209   1.159495   0.937644
# min      3.070000   1.000000   1.000000
# 25%     12.750000   2.000000   2.000000
# 50%     16.400000   2.750000   2.000000
# 75%     21.520000   3.500000   3.000000
# max     44.300000   6.500000   6.000000
# sex - Male
#        total_bill         tip        size
# count  157.000000  157.000000  157.000000
# mean    20.744076    3.089618    2.630573
# std      9.246469    1.489102    0.955997
# min      7.250000    1.000000    1.000000
# 25%     14.000000    2.000000    2.000000
# 50%     18.350000    3.000000    2.000000
# 75%     24.710000    3.760000    3.000000
# max     50.810000   10.000000    6.000000
# smoker - No
#        total_bill         tip        size
# count  151.000000  151.000000  151.000000
# mean    19.188278    2.991854    2.668874
# std      8.255582    1.377190    1.017984
# ...

# %%
df[['total_bill', 'tip', 'size']].mean()
# Out:
# total_bill    19.785943
# tip            2.998279
# size           2.569672
# dtype: float64

# %%
df[['total_bill', 'tip', 'size']].median()
# Out:
# total_bill    17.795
# tip            2.900
# size           2.000
# dtype: float64

# %%
df[['total_bill', 'tip', 'size']].std()

df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
ds
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
ds_dict = pd.DataFrame([
    {
        "variavel":"survived",
        "descricao":"número de sobreviventes",
        "tipo": "quantitativa",
        "subtipo": "discretas"
    },{
        "variavel": "pclass",
        "descricao": "classe do navio",
        "tipo": "qualitativa",
        "subtipo": "ordinal",
    },{
        "variavel":"sex",
        "descricao": "refere-se ao sexo da pessoa",
        "tipo":"qualitativa",
        "subtipo":"nominal",
    },{
        "variavel":"age",
        "descricao": "idade",
        "tipo":"quantitativa",
        "subtipo":"discreta",
    },{
        "variavel":"sibsp",
        "descricao":"acompanhante",
        "tipo":"quantitativa",
        "subtipo":"discreta",
    },{
        "variavel":"parch",
        "descricao":"ressecado",
        "tipo":"qualitativa",
        "subtipo":"nominal",
    },{
        "variavel":"fare",
        "descricao":"número de passagem",
        "tipo":"quantitativa",
        "subtipo":"discreta",
    },{
        "variavel":"embark_town",
        "descricao":"cidade de embarque",
        "tipo":"qualitativa",
        "subtipo":"nominal",
    },{
        "variavel":"alive",
        "descricao":"se a pessoa está viva",
        "tipo":"qualitativa",
        "subtipo":"nominal",
    },{
        "variavel":"alone",
        "descricao":"se a pessoa está sozinha",
        "tipo":"qualitativa",
        "subtipo":"nominal",
    },{
        "variavel":"embarked",
        "descricao":"embarcado",
        "tipo":"qualitativa",
        "subtipo":"nominal",
    },{
        "variavel":"class",
        "descricao":"categoria",
        "tipo":"qualitativa",
        "subtipo":"ordinal",
    },{
        "variavel":"who",
        "descricao":"quem",
        "tipo":"qualitativa",
        "subtipo":"nominal",
    },{
        "variavel":"adult_male",
        "descricao":"se é um adulto masculino",
        "tipo":"qualitativa",
        "subtipo":"nominal",
    },{
        "variavel":"deck",
        "descricao":"área com deck",
        "tipo":"qualitativa",
        "subtipo":"nominal",
    }
    
])

ds_dict
# Out:
#        variavel                    descricao          tipo    subtipo
# 0      survived      número de sobreviventes  quantitativa  discretas
# 1        pclass              classe do navio   qualitativa    ordinal
# 2           sex  refere-se ao sexo da pessoa   qualitativa    nominal
# 3           age                        idade  quantitativa   discreta
# 4         sibsp                 acompanhante  quantitativa   discreta
# 5         parch                    ressecado   qualitativa    nominal
# 6          fare           número de passagem  quantitativa   discreta
# 7   embark_town           cidade de embarque   qualitativa    nominal
# 8         alive        se a pessoa está viva   qualitativa    nominal
# 9         alone     se a pessoa está sozinha   qualitativa    nominal
# 10     embarked                    embarcado   qualitativa    nominal
# 11        class                    categoria   qualitativa    ordinal
# ...

# %%
ds[['survived', 'age', 'sibsp', 'fare']].mean()
# Out:
# survived     0.383838
# age         29.699118
# sibsp        0.523008
# fare        32.204208
# dtype: float64

# %%
ds[['survived', 'age', 'sibsp', 'fare']].median()
# Out:
# survived     0.0000
# age         28.0000
# sibsp        0.0000
# fare        14.4542
# dtype: float64

# %%
ds[['survived', 'age', 'sibsp', 'fare']].std()

ds.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
ds[['pclass', 'sex', 'parch', 'embark_town', 'alive', 'alone', 'embarked', 'class', 'who','adult_male','deck']].mode()
# Out:
#    pclass   sex  parch  embark_town alive  alone embarked  class  who  \
# 0       3  male      0  Southampton    no   True        S  Third  man
#
#    adult_male deck
# 0        True    C

# %%
qualitive_vars =['pclass', 'sex', 'parch', 'embark_town', 'alive', 'alone', 'embarked', 'class', 'who','adult_male','deck']

for variavel in qualitive_vars:
    valores_unicos = ds[variavel].unique()
    for valor in valores_unicos:
        print(f"{variavel} - {valor}")
        subamostras = ds[ds[variavel] == valor]
        print(subamostras.describe())
# Out:
# pclass - 3
#          survived  pclass         age       sibsp       parch        fare
# count  491.000000   491.0  355.000000  491.000000  491.000000  491.000000
# mean     0.242363     3.0   25.140620    0.615071    0.393075   13.675550
# std      0.428949     0.0   12.495398    1.374883    0.888861   11.778142
# min      0.000000     3.0    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000     3.0   18.000000    0.000000    0.000000    7.750000
# 50%      0.000000     3.0   24.000000    0.000000    0.000000    8.050000
# 75%      0.000000     3.0   32.000000    1.000000    0.000000   15.500000
# max      1.000000     3.0   74.000000    8.000000    6.000000   69.550000
# pclass - 1
#          survived  pclass         age       sibsp       parch        fare
# count  216.000000   216.0  186.000000  216.000000  216.000000  216.000000
# mean     0.629630     1.0   38.233441    0.416667    0.356481   84.154687
# ...
